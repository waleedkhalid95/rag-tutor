# %%
pip install --upgrade --quiet langchain_community tiktoken langchain-huggingface langchainhub chromadb langchain llama-index huggingface-hub pypdf pytest
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 79.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 84.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = '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'

# %%
import bs4
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.schema import Document
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# Step 1: Load the file content
with open('/content/output_ocr.txt', 'r') as file:
    text_content = file.read()

# Step 2: Create a Document object
doc = Document(page_content=text_content, metadata={"source": "output_ocr.txt"})

# Step 3: Pass the list of Document objects to split_documents
text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=50)
splits = text_splitter.split_documents([doc])

# %%
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
import getpass

#inference_api_key = getpass.getpass("Enter your HF Inference API Key:\n\n")
embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key="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", model_name="dunzhang/stella_en_1.5B_v5"
)

# %%
vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6e07217d9da2> in <cell line: 1>()
# ----> 1 vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings)
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/chroma.py in from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     876         texts = [doc.page_content for doc in documents]
#     877         metadatas = [doc.metadata for doc in documents]
# --> 878         return cls.from_texts(
#     879             texts=texts,
#     880             embedding=embedding,
#
# ...

# %%
retriever = vectorstore.as_retriever()
prompt = hub.pull("rlm/rag-prompt")

# %%
# Generate embeddings for each document chunk
chunk_embeddings = [embeddings.embed_documents([doc.page_content]) for doc in splits]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3f735c508434> in <cell line: 2>()
#       1 # Generate embeddings for each document chunk
# ----> 2 chunk_embeddings = [embeddings.embed_documents([doc.page_content]) for doc in splits]
#
# <ipython-input-9-3f735c508434> in <listcomp>(.0)
#       1 # Generate embeddings for each document chunk
# ----> 2 chunk_embeddings = [embeddings.embed_documents([doc.page_content]) for doc in splits]
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/embeddings/huggingface.py in embed_documents(self, texts)
#     405                 hf_embeddings.embed_documents(texts)
#     406         """  # noqa: E501
# --> 407         response = requests.post(
#     408             self._api_url,
#     409             headers=self._headers,
#
# ...
