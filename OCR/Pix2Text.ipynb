# %% [markdown]
# #Pix2Text

# %%
# !pip install -qU pix2text langchain jq tiktoken langchain_community langchain_chroma langchain-huggingface huggingface-hub sentence_transformers
# !pip uninstall onnxruntime -y
# !pip install -qU onnxruntime-gpu
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.6/163.6 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.1/222.1 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 95.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 96.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 98.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 92.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.7/453.7 kB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 43.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 103.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.4/311.4 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.8 MB/s eta 0:00:00
#   Building wheel for Polygon3 (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Found existing installation: onnxruntime 1.19.2
# Uninstalling onnxruntime-1.19.2:
#   Successfully uninstalled onnxruntime-1.19.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.2/226.2 MB 3.5 MB/s eta 0:00:00

# %%
from pix2text import Pix2Text
from pix2text.latex_ocr import *

img_fp = '/content/chapter1.pdf'
p2t = Pix2Text.from_config()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /usr/local/lib/python3.10/dist-packages/pix2text/doc_xl_layout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# WARNING:cnocr.recognizer:no onnx file is found in /root/.cnocr/2.3/densenet_lite_136-gru
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# densenet_lite_136-gru-onnx.zip:   0%|          | 0.00/11.6M [00:00<?, ?B/s]
# WARNING:cnstd.ppocr.pp_detector:can not find model file /root/.cnstd/1.2/ppocr/ch_PP-OCRv3_det_infer.onnx
# ch_PP-OCRv3_det_infer-onnx.zip:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/python/onnxruntime_pybind_state.cc:490 void onnxruntime::python::RegisterTensorRTPluginsAsCustomOps(PySessionOptions&, const onnxruntime::ProviderOptions&) Please install TensorRT libraries as mentioned in the GPU requirements page, make sure they're in the PATH or LD_LIBRARY_PATH, and that your GPU is supported.
#  when using ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CUDAExecutionProvider', 'CPUExecutionProvider'] and retrying.
# ****************************************

# %% [markdown]
# ## Page by page

# %%
#page by page
from langchain_core.documents import Document
pages=[]
for i in range(0,25):
  doc = p2t.recognize_pdf(img_fp,table_as_image=False,page_numbers=[i])
  pages.append(Document(page_content=doc.to_markdown('Page'), metadata={'page':i}))
# Out:
# Loading /root/.pix2text/1.1/mfd-onnx/mfd-v20240618.onnx for ONNX Runtime inference...
#
# WARNING ⚠️ imgsz=[421, 1152] must be multiple of max stride 32, updating to [448, 1152]
# 0: 448x1152 (no detections), 24.7ms
# Speed: 4.8ms preprocess, 24.7ms inference, 84.6ms postprocess per image at shape (1, 3, 448, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[419, 1152] must be multiple of max stride 32, updating to [448, 1152]
# 0: 448x1152 (no detections), 21.7ms
# Speed: 3.8ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[196, 1152] must be multiple of max stride 32, updating to [224, 1152]
# 0: 224x1152 (no detections), 8459.4ms
# Speed: 2.7ms preprocess, 8459.4ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[247, 768] must be multiple of max stride 32, updating to [256, 768]
# 0: 256x768 1 isolated, 2379.8ms
# Speed: 2.6ms preprocess, 2379.8ms inference, 672.0ms postprocess per image at shape (1, 3, 256, 768)
# 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# WARNING ⚠️ imgsz=[1282, 768] must be multiple of max stride 32, updating to [1312, 768]
# 0: 1312x768 (no detections), 7800.6ms
# Speed: 7.7ms preprocess, 7800.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1312, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[598, 1152] must be multiple of max stride 32, updating to [608, 1152]
# 0: 608x1152 (no detections), 7880.5ms
# Speed: 5.2ms preprocess, 7880.5ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[412, 1152] must be multiple of max stride 32, updating to [416, 1152]
# 0: 416x1152 (no detections), 8406.1ms
# Speed: 3.8ms preprocess, 8406.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[233, 1152] must be multiple of max stride 32, updating to [256, 1152]
# 0: 256x1152 (no detections), 8346.7ms
# Speed: 2.9ms preprocess, 8346.7ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[280, 1152] must be multiple of max stride 32, updating to [288, 1152]
# 0: 288x1152 (no detections), 8151.0ms
# Speed: 2.5ms preprocess, 8151.0ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[131, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 7740.8ms
# Speed: 1.7ms preprocess, 7740.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[162, 768] must be multiple of max stride 32, updating to [192, 768]
# 0: 192x768 1 embedding, 2337.8ms
# Speed: 2.0ms preprocess, 2337.8ms inference, 1.8ms postprocess per image at shape (1, 3, 192, 768)
# 100%|██████████| 1/1 [00:00<00:00, 13.97it/s]
# WARNING ⚠️ imgsz=[1251, 768] must be multiple of max stride 32, updating to [1280, 768]
# 0: 1280x768 (no detections), 7796.9ms
# Speed: 7.5ms preprocess, 7796.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[264, 1152] must be multiple of max stride 32, updating to [288, 1152]
# 0: 288x1152 (no detections), 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[232, 1152] must be multiple of max stride 32, updating to [256, 1152]
# 0: 256x1152 1 embedding, 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 20.81it/s]
# WARNING ⚠️ imgsz=[429, 1152] must be multiple of max stride 32, updating to [448, 1152]
# 0: 448x1152 (no detections), 21.7ms
# Speed: 3.4ms preprocess, 21.7ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[273, 1152] must be multiple of max stride 32, updating to [288, 1152]
# 0: 288x1152 (no detections), 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[254, 768] must be multiple of max stride 32, updating to [256, 768]
# 0: 256x768 1 isolated, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 768)
# 100%|██████████| 1/1 [00:00<00:00,  9.81it/s]
# WARNING ⚠️ imgsz=[129, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 0.7ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.54s/it]
# 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 0: 128x768 (no detections), 1384.3ms
# Speed: 1.1ms preprocess, 1384.3ms inference, 0.8ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[1255, 768] must be multiple of max stride 32, updating to [1280, 768]
# 0: 1280x768 1 embedding, 14.3ms
# Speed: 7.2ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 768)
# 100%|██████████| 1/1 [00:00<00:00, 13.17it/s]
# WARNING ⚠️ imgsz=[172, 768] must be multiple of max stride 32, updating to [192, 768]
# 0: 192x768 2 isolateds, 8.2ms
# Speed: 1.2ms preprocess, 8.2ms inference, 3.4ms postprocess per image at shape (1, 3, 192, 768)
# 100%|██████████| 1/1 [00:00<00:00,  8.06it/s]
# WARNING ⚠️ imgsz=[359, 768] must be multiple of max stride 32, updating to [384, 768]
# 0: 384x768 1 isolated, 1571.7ms
# Speed: 2.2ms preprocess, 1571.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 768)
# 100%|██████████| 1/1 [00:00<00:00, 16.89it/s]
# WARNING ⚠️ imgsz=[290, 768] must be multiple of max stride 32, updating to [320, 768]
# 0: 320x768 1 isolated, 1398.5ms
# Speed: 1.6ms preprocess, 1398.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 768)
# 100%|██████████| 1/1 [00:00<00:00, 16.70it/s]
# WARNING ⚠️ imgsz=[447, 768] must be multiple of max stride 32, updating to [448, 768]
# 0: 448x768 3 isolateds, 1313.6ms
# Speed: 3.0ms preprocess, 1313.6ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 768)
# 100%|██████████| 1/1 [00:00<00:00,  4.92it/s]
# WARNING ⚠️ imgsz=[298, 768] must be multiple of max stride 32, updating to [320, 768]
# 0: 320x768 1 isolated, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 768)
# 100%|██████████| 1/1 [00:00<00:00, 14.35it/s]
# WARNING ⚠️ imgsz=[362, 768] must be multiple of max stride 32, updating to [384, 768]
# 0: 384x768 1 isolated, 18.2ms
# Speed: 2.8ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 768)
# 100%|██████████| 1/1 [00:00<00:00, 11.98it/s]
# WARNING ⚠️ imgsz=[267, 768] must be multiple of max stride 32, updating to [288, 768]
# 0: 288x768 1 isolated, 1316.6ms
# Speed: 1.6ms preprocess, 1316.6ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 768)
# 100%|██████████| 1/1 [00:00<00:00, 12.07it/s]
# WARNING ⚠️ imgsz=[294, 768] must be multiple of max stride 32, updating to [320, 768]
# 0: 320x768 1 isolated, 18.2ms
# Speed: 1.5ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 768)
# 100%|██████████| 1/1 [00:00<00:00, 15.77it/s]
# WARNING ⚠️ imgsz=[107, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 1 embedding, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 128, 768)
# 100%|██████████| 1/1 [00:00<00:00, 45.91it/s]
# WARNING ⚠️ imgsz=[122, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 1 isolated, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 128, 768)
# 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# WARNING ⚠️ imgsz=[227, 1152] must be multiple of max stride 32, updating to [256, 1152]
# 0: 256x1152 4 embeddings, 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 1152)
# 100%|██████████| 4/4 [00:00<00:00, 34.43it/s]
# WARNING ⚠️ imgsz=[166, 1152] must be multiple of max stride 32, updating to [192, 1152]
# 0: 192x1152 (no detections), 8479.0ms
# Speed: 2.1ms preprocess, 8479.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[156, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 0.7ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[191, 1152] must be multiple of max stride 32, updating to [192, 1152]
# 0: 192x1152 2 embeddings, 18.1ms
# Speed: 3.5ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 1152)
# 100%|██████████| 2/2 [00:00<00:00, 34.18it/s]
# WARNING ⚠️ imgsz=[339, 768] must be multiple of max stride 32, updating to [352, 768]
# 0: 352x768 1 isolated, 2114.3ms
# Speed: 2.4ms preprocess, 2114.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 768)
# 100%|██████████| 1/1 [00:00<00:00, 13.92it/s]
# WARNING ⚠️ imgsz=[162, 1152] must be multiple of max stride 32, updating to [192, 1152]
# 0: 192x1152 (no detections), 18.2ms
# Speed: 2.4ms preprocess, 18.2ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[121, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 (no detections), 8566.2ms
# Speed: 1.5ms preprocess, 8566.2ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[171, 1152] must be multiple of max stride 32, updating to [192, 1152]
# 0: 192x1152 (no detections), 18.2ms
# Speed: 1.8ms preprocess, 18.2ms inference, 1.4ms postprocess per image at shape (1, 3, 192, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[162, 1152] must be multiple of max stride 32, updating to [192, 1152]
# 0: 192x1152 (no detections), 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 1152)
# 0it [00:00, ?it/s]
# 0: 160x1152 1 embedding, 18.1ms
# Speed: 2.3ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 13.34it/s]
# WARNING ⚠️ imgsz=[164, 768] must be multiple of max stride 32, updating to [192, 768]
# 0: 192x768 1 embedding, 1 isolated, 17.0ms
# Speed: 1.1ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 192, 768)
# 100%|██████████| 1/1 [00:00<00:00,  5.84it/s]
# WARNING ⚠️ imgsz=[1281, 768] must be multiple of max stride 32, updating to [1312, 768]
# 0: 1312x768 (no detections), 14.8ms
# Speed: 7.7ms preprocess, 14.8ms inference, 0.8ms postprocess per image at shape (1, 3, 1312, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[273, 1152] must be multiple of max stride 32, updating to [288, 1152]
# 0: 288x1152 (no detections), 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 5.9ms postprocess per image at shape (1, 3, 288, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[119, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 1 embedding, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 128, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 12.39it/s]
# WARNING ⚠️ imgsz=[205, 1152] must be multiple of max stride 32, updating to [224, 1152]
# 0: 224x1152 8 embeddings, 18.1ms
# Speed: 2.3ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 1152)
# 100%|██████████| 7/7 [00:00<00:00, 28.09it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.55it/s]
# WARNING ⚠️ imgsz=[207, 1152] must be multiple of max stride 32, updating to [224, 1152]
# 0: 224x1152 4 embeddings, 18.2ms
# Speed: 2.5ms preprocess, 18.2ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 1152)
# 100%|██████████| 4/4 [00:00<00:00, 26.36it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# WARNING ⚠️ imgsz=[134, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# WARNING ⚠️ imgsz=[132, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 3 embeddings, 7.6ms
# Speed: 1.4ms preprocess, 7.6ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 1152)
# 100%|██████████| 2/2 [00:00<00:00, 24.40it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
# 0: 128x1152 (no detections), 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# WARNING ⚠️ imgsz=[75, 768] must be multiple of max stride 32, updating to [96, 768]
# 0: 96x768 1 embedding, 1757.7ms
# Speed: 1.2ms preprocess, 1757.7ms inference, 1.5ms postprocess per image at shape (1, 3, 96, 768)
# 100%|██████████| 1/1 [00:00<00:00, 15.20it/s]
# WARNING ⚠️ imgsz=[465, 768] must be multiple of max stride 32, updating to [480, 768]
# 0: 480x768 1 isolated, 2134.4ms
# Speed: 2.5ms preprocess, 2134.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 768)
# 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
# WARNING ⚠️ imgsz=[124, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 3 embeddings, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 128, 1152)
# 100%|██████████| 3/3 [00:00<00:00, 25.81it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.85it/s]
# WARNING ⚠️ imgsz=[107, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 15.2ms
# Speed: 1.1ms preprocess, 15.2ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[119, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 15.2ms
# Speed: 0.9ms preprocess, 15.2ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[1319, 768] must be multiple of max stride 32, updating to [1344, 768]
# 0: 1344x768 (no detections), 7809.6ms
# Speed: 7.6ms preprocess, 7809.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1344, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[353, 1152] must be multiple of max stride 32, updating to [384, 1152]
# 0: 384x1152 7 embeddings, 7743.0ms
# Speed: 2.9ms preprocess, 7743.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 1152)
# 100%|██████████| 7/7 [00:00<00:00, 22.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# WARNING ⚠️ imgsz=[131, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 2 embeddings, 18.2ms
# Speed: 1.5ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 1152)
# 100%|██████████| 2/2 [00:00<00:00, 30.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.61it/s]
# WARNING ⚠️ imgsz=[129, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[235, 1152] must be multiple of max stride 32, updating to [256, 1152]
# 0: 256x1152 1 embedding, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 26.74it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.93it/s]
# WARNING ⚠️ imgsz=[133, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[167, 1152] must be multiple of max stride 32, updating to [192, 1152]
# 0: 192x1152 (no detections), 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[199, 1152] must be multiple of max stride 32, updating to [224, 1152]
# 0: 224x1152 2 embeddings, 18.2ms
# Speed: 2.4ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 1152)
# 100%|██████████| 2/2 [00:00<00:00, 30.66it/s]
# WARNING ⚠️ imgsz=[169, 768] must be multiple of max stride 32, updating to [192, 768]
# 0: 192x768 2 embeddings, 1 isolated, 17.1ms
# Speed: 1.8ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 768)
# 100%|██████████| 1/1 [00:00<00:00,  5.85it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.23it/s]
# WARNING ⚠️ imgsz=[1279, 768] must be multiple of max stride 32, updating to [1280, 768]
# 0: 1280x768 (no detections), 14.0ms
# Speed: 7.4ms preprocess, 14.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[107, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 7.4ms
# Speed: 1.2ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[158, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 1 embedding, 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 30.21it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.38it/s]
# WARNING ⚠️ imgsz=[129, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# WARNING ⚠️ imgsz=[133, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 13.2ms
# Speed: 1.6ms preprocess, 13.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.52it/s]
# WARNING ⚠️ imgsz=[89, 768] must be multiple of max stride 32, updating to [96, 768]
# 0: 96x768 (no detections), 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 0.6ms postprocess per image at shape (1, 3, 96, 768)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.66it/s]
# WARNING ⚠️ imgsz=[79, 768] must be multiple of max stride 32, updating to [96, 768]
# 0: 96x768 (no detections), 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 0.7ms postprocess per image at shape (1, 3, 96, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[119, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 1 embedding, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 128, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 25.62it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
# WARNING ⚠️ imgsz=[99, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 1 embedding, 7.7ms
# Speed: 0.9ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 128, 768)
# 100%|██████████| 1/1 [00:00<00:00, 34.52it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
# WARNING ⚠️ imgsz=[130, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 3 embeddings, 17.1ms
# Speed: 1.5ms preprocess, 17.1ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 1152)
# 100%|██████████| 3/3 [00:00<00:00, 27.32it/s]
# WARNING ⚠️ imgsz=[110, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 6.8ms
# Speed: 0.8ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[1272, 768] must be multiple of max stride 32, updating to [1280, 768]
# 0: 1280x768 (no detections), 13.9ms
# Speed: 7.3ms preprocess, 13.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1280, 768)
# 0it [00:00, ?it/s]
# 0: 128x1152 (no detections), 7.8ms
# Speed: 1.2ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# WARNING ⚠️ imgsz=[126, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 1 embedding, 7.4ms
# Speed: 1.3ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 128, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 28.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.97it/s]
# WARNING ⚠️ imgsz=[137, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 1 embedding, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 11.77it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.88it/s]
# WARNING ⚠️ imgsz=[127, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 1 embedding, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 1.4ms postprocess per image at shape (1, 3, 128, 1152)
# 100%|██████████| 1/1 [00:00<00:00, 28.89it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.91it/s]
# WARNING ⚠️ imgsz=[154, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[75, 768] must be multiple of max stride 32, updating to [96, 768]
# 0: 96x768 (no detections), 15.2ms
# Speed: 1.7ms preprocess, 15.2ms inference, 0.6ms postprocess per image at shape (1, 3, 96, 768)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.64it/s]
# WARNING ⚠️ imgsz=[133, 1152] must be multiple of max stride 32, updating to [160, 1152]
# 0: 160x1152 (no detections), 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# WARNING ⚠️ imgsz=[107, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 0.8ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[121, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 (no detections), 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 1152)
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# WARNING ⚠️ imgsz=[73, 768] must be multiple of max stride 32, updating to [96, 768]
# 0: 96x768 1 embedding, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 96, 768)
# 100%|██████████| 1/1 [00:00<00:00,  7.11it/s]

# %% [markdown]
# # Langchain

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline, HuggingFaceEmbeddings
from langchain_community.embeddings import HuggingFaceInstructEmbeddings, HuggingFaceBgeEmbeddings, HuggingFaceHubEmbeddings, HuggingFaceHubEmbeddings
from langchain_huggingface import HuggingFacePipeline

# %%
import bs4, getpass, os, tiktoken
from langchain import hub
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain.prompts import ChatPromptTemplate

# Load, chunk and index the contents of the blog.
loader = TextLoader("/content/output/output.md")
docs = loader.load()

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens
#num_tokens_from_string(question, "cl100k_base")
def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)
#similarity = cosine_similarity(query_result, document_result)

# %%
model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cuda:0"}
encode_kwargs = {"normalize_embeddings": True}
hf = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
question = "What Ideal gas law?"
document = docs

# %%
document

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
splits = text_splitter.split_documents(document)
vectorstore = Chroma.from_documents(documents=splits, embedding=hf)
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# %%
docs = retriever.get_relevant_documents(question)
len(docs)
